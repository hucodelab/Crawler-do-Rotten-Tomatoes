# %%
# ls

# %%
import pandas as pd
import numpy as np
import pickle
import json
import re

from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# preparamos o driver do Chrome
driver = webdriver.Chrome('path/chromedriver')
# Out:
# <ipython-input-3-c16ba3ec765d>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('path/chromedriver')

# %%
# fazemos a importacao do dataset do TMDB
df0 = pd.read_csv('movies_trending.csv')

# %% [markdown]
# # Criacao do dataset com os dados do Rotten Tomatoes

# %%
# criamos esta funcao para que os nomes dos filmes sejam transformados nos nomes dos filmes da url
# exemplo: The Matrix ---> the_matrix, desta forma conseguimos acessar as urls

def rottenize(title):
    '''
    Esta funcao sustitui os carateres por vazio ou por _
    para depois entrar nos links (urls) dos filmes no rotten
    '''
    title = title.translate(str.maketrans({':': '', "'": '', ".":"", ",":"", 
                                          "-":"_", " ":"_"}))
    return title

# %%
# criamos uma lista vazia para armazenar as urls dos filmes do dataset do TMDB
links = []
for tit in df0['original_title'].apply(rottenize):
    links.append('https://www.rottentomatoes.com/m/{}'.format(tit))

# %%
# selecionamos um pedaco da lista de links de filmes comencando pelo "start"
# links = links[start:]

def create_df(n):
    '''
    n: numero de filmes a coletar
    start: numero da lista do link do filme que vamos comecar a coletar
    '''  
    # neste dataset iremos armazenar as informacoes extraidas do Rotten Tomatoes
    df = pd.DataFrame()
    
    # listas para armazenar a informacao
    nomes = []
    TOMATOMETER = []
    TOMATOMETER_rev = []
    aud_scr = []
    aud_scr_rev = []

    genre = []
    language = []
    director = []
    producer = []
    writer = []
    rel_date_th = []
    rel_date_stream = []
    box = []
    runtime = []
    distributor = []
    description = []

#     for k in range(1000):
#     #     driver.get('https://www.rottentomatoes.com/browse/movies_in_theaters/?page={}'.format(j))
#         url = 'https://www.rottentomatoes.com/browse/movies_in_theaters/?page={}'.format(k)
#     #     print(url, end="\r", flush=True)


    for j in range(len(links[:n])):
        
        # mostra quantos filmes ja varreu
        print(j, end="\r", flush=True)
        
        # entramos no site do filme
        driver.get(links[j])
        
        # se aparecer algun erro no navegador voltamos ao comeco do loop
        try:
            # informacoes da descricao do filme
            info_we = driver.find_elements(By.CLASS_NAME, "media-body")
            # informações mais breves da descricao
            short_info = info_we[0].text.split('\n')[2:]

            # informacoes principais do filme: nome, scores e quantidade de reviews
            info_main = driver.find_elements(By.CLASS_NAME, "scoreboard")
            info_main = info_main[0].text.split('\n')

            # dicionario para armazenar as infos do filme
            short_info_dic = dict()

            # acrescentamos tambem as informacoes principais
            short_info_dic['Nome'] = info_main[0]
            short_info_dic['TOMATOMETER'] = info_main[2]
            short_info_dic['TOMATOMETER reviews'] = info_main[4]
            short_info_dic['AUDIENCE SCORE'] = info_main[5]
            short_info_dic['AUDIENCE SCORE reviews'] = info_main[7]
        except:
            continue

        # informacoes breves do filme
        for i in range(len(short_info)):
            infos = short_info[i].split(': ')
            try:
                short_info_dic[infos[0]] = infos[1]
            except:
                short_info_dic[infos[0]] = np.nan

        # resumo e descricao do filme
        short_info_dic[info_we[0].text.split('\n')[0]] = info_we[0].text.split('\n')[1]

        # colocamos as informacoes nas listas
        try:
            nomes.append(short_info_dic['Nome'])
        except:
            nomes.append(np.nan)
        
        try:
            TOMATOMETER.append(short_info_dic['TOMATOMETER'])
        except:
            TOMATOMETER.append(np.nan)
        
        try:
            TOMATOMETER_rev.append(short_info_dic['TOMATOMETER reviews'])
        except:
            TOMATOMETER_rev.append(np.nan)
        
        try:
            aud_scr.append(short_info_dic['AUDIENCE SCORE'])
        except:
            aud_scr.append(np.nan)
        
        try:
            aud_scr_rev.append(short_info_dic['AUDIENCE SCORE reviews'])
        except:
            aud_scr_rev.append(np.nan)
        
        try:
            genre.append(short_info_dic['Genre'])
        except:
            genre.append(np.nan)
        
        try:
            language.append(short_info_dic['Original Language'])
        except:
            language.append(np.nan)
        
        try:
            director.append(short_info_dic['Director'])
        except:
            director.append(np.nan)
        
        try:
            producer.append(short_info_dic['Producer'])
        except:
            producer.append(np.nan)
        
        try:
            writer.append(short_info_dic['Writer'])
        except:
            writer.append(np.nan)
        
        try:
            rel_date_th.append(short_info_dic['Release Date (Theaters)'])
        except:
            rel_date_th.append(np.nan)
        
        try:
            rel_date_stream.append(short_info_dic['Release Date (Streaming)'])
        except:
            rel_date_stream.append(np.nan)
        
        try:
            box.append(short_info_dic['Box Office (Gross USA)'])
        except:
            box.append(np.nan)
        
        try:
            runtime.append(short_info_dic['Runtime'])
        except:
            runtime.append(np.nan)
        
        try:
            distributor.append(short_info_dic['Distributor'])
        except:
            distributor.append(np.nan)
            
        try:
            description.append(short_info_dic['MOVIE INFO'])
        except:
            description.append(np.nan)
        
    df = pd.DataFrame() 

    df['Movie Name'] = nomes
    df['Audience Score'] = aud_scr
    df['AUDIENCE SCORE reviews'] = aud_scr_rev
    df['Tomatometer Score'] = TOMATOMETER
    df['TOMATOMETER reviews'] = nomes
    df['Genre'] = genre
    df['Original Language'] = language
    df['Director'] = director
    df['Producer'] = producer
    df['Writer'] = writer
    df['Release Date (Theaters)'] = rel_date_th
    df['Release Date (Streaming)'] = rel_date_stream
    df['box office'] = box
    df['Runtime'] = runtime
    df['Distributor'] = distributor
    df['MOVIE INFO'] = description
        
    return df

# %%
df = create_df(len(links))
# Out:
# 59

# %%
df
# Out:
#                                      Movie Name Audience Score  \
# 0                                    BLACK ADAM            89%
# 1                BLACK PANTHER: WAKANDA FOREVER            94%
# 2                              THE DISENCHANTED            42%
# 3                                   SLUMBERLAND            87%
# 4                                      SPIRITED            82%
# 5                                         SMILE             --
# 6                                ENOLA HOLMES 2            78%
# 7                                    THE WONDER             --
# 8                             TOP GUN: MAVERICK            99%
# 9                                     AMSTERDAM            19%
# 10                               THE WOMAN KING            99%
# 11                          DON'T WORRY DARLING            74%
# 12                                 BULLET TRAIN            57%
# 13            THE PEOPLE WE HATE AT THE WEDDING            41%
# 14                                THE BARBARIAN             --
# 15       LAMBORGHINI: THE MAN BEHIND THE LEGEND            27%
# 16               R.I.P.D. 2: RISE OF THE DAMNED            25%
# 17                       THOR: LOVE AND THUNDER            77%
# 18                                         NOPE            69%
# 19                      A SNOW CAPPED CHRISTMAS            42%
# 20                     AVATAR: THE WAY OF WATER             --
# 21                                   POKER FACE             --
# 22                             SEE HOW THEY RUN            69%
# 23                      SPIDER-MAN: NO WAY HOME            98%
# 24                  A CHRISTMAS STORY CHRISTMAS            80%
# 25                           CHRISTMAS WITH YOU            65%
# 26                                     THE MENU            77%
# 27                           TICKET TO PARADISE             --
# 28                                     CAUSEWAY            75%
# 29                           MY FATHER'S DRAGON             --
# 30                                  ON THE LINE             --
# 31                 WEIRD: THE AL YANKOVIC STORY            83%
# 32                        LYLE, LYLE, CROCODILE            93%
# 33                                 MY POLICEMAN            96%
# 34                                  TERRIFIER 2            80%
# 35  DOCTOR STRANGE IN THE MULTIVERSE OF MADNESS            85%
# 36                               HALLOWEEN ENDS            57%
# 37                                       AVATAR            82%
# 38                                     MEDIEVAL            72%
# 39                              ARMAGEDDON TIME            48%
# 40                    THE SOCCER FOOTBALL MOVIE            19%
# 41                               THE GOOD NURSE            77%
# 42                                   THE BATMAN            87%
# 43                TOM AND JERRY: SNOWMAN'S LAND             --
# 44                                BLACK PANTHER            50%
# 45            EVERYTHING EVERYWHERE ALL AT ONCE            89%
# 46                                        BEAST            74%
# 47                                        PEARL             --
# 48                      JURASSIC WORLD DOMINION            77%
# 49                             THE LAST MANHUNT            42%
# 50                     MINIONS: THE RISE OF GRU            89%
# 51                                PARADISE CITY             --
# 52                          TRIANGLE OF SADNESS            73%
# 53                           ONE PIECE FILM RED            95%
#
#       AUDIENCE SCORE reviews Tomatometer Score  \
# 0    5,000+ Verified Ratings               39%
# 1   10,000+ Verified Ratings               84%
# 2               250+ Ratings              100%
# 3               500+ Ratings               37%
# 4      100+ Verified Ratings               69%
# 5                  0 Ratings                --
# 6             1,000+ Ratings               94%
# 7                  0 Ratings                --
# 8   50,000+ Verified Ratings               96%
# 9                50+ Ratings                --
# 10   5,000+ Verified Ratings               94%
# 11   1,000+ Verified Ratings               38%
# 12              100+ Ratings                --
# 13              100+ Ratings               34%
# 14     Fewer than 50 Ratings                --
# 15               50+ Ratings                8%
# 16              100+ Ratings                --
# 17  10,000+ Verified Ratings               64%
# 18   5,000+ Verified Ratings               82%
# 19     Fewer than 50 Ratings                --
# 20                 0 Ratings                --
# 21                 0 Ratings                --
# 22     500+ Verified Ratings               74%
# 23  25,000+ Verified Ratings               93%
# 24              250+ Ratings               78%
# 25              100+ Ratings               67%
# 26   1,000+ Verified Ratings               89%
# 27     Fewer than 50 Ratings                --
# 28              250+ Ratings               86%
# 29                 0 Ratings                --
# 30     Fewer than 50 Ratings                --
# 31              500+ Ratings               84%
# 32   1,000+ Verified Ratings               73%
# 33     100+ Verified Ratings               44%
# 34     500+ Verified Ratings               86%
# 35  10,000+ Verified Ratings               74%
# 36   2,500+ Verified Ratings               40%
# 37          250,000+ Ratings               82%
# 38     100+ Verified Ratings               41%
# 39     100+ Verified Ratings               76%
# 40     Fewer than 50 Ratings                --
# 41              500+ Ratings               76%
# 42  10,000+ Verified Ratings               85%
# 43     Fewer than 50 Ratings                --
# 44     Fewer than 50 Ratings                --
# 45   2,500+ Verified Ratings               95%
# 46            1,000+ Ratings               92%
# 47     Fewer than 50 Ratings                --
# 48  10,000+ Verified Ratings               29%
# 49     Fewer than 50 Ratings               20%
# 50  10,000+ Verified Ratings               70%
# 51     Fewer than 50 Ratings                --
# 52              500+ Ratings               70%
# 53   1,000+ Verified Ratings               94%
#
#                             TOMATOMETER reviews  \
# 0                                    BLACK ADAM
# 1                BLACK PANTHER: WAKANDA FOREVER
# 2                              THE DISENCHANTED
# 3                                   SLUMBERLAND
# 4                                      SPIRITED
# 5                                         SMILE
# 6                                ENOLA HOLMES 2
# 7                                    THE WONDER
# 8                             TOP GUN: MAVERICK
# 9                                     AMSTERDAM
# 10                               THE WOMAN KING
# 11                          DON'T WORRY DARLING
# 12                                 BULLET TRAIN
# 13            THE PEOPLE WE HATE AT THE WEDDING
# 14                                THE BARBARIAN
# 15       LAMBORGHINI: THE MAN BEHIND THE LEGEND
# 16               R.I.P.D. 2: RISE OF THE DAMNED
# 17                       THOR: LOVE AND THUNDER
# 18                                         NOPE
# 19                      A SNOW CAPPED CHRISTMAS
# 20                     AVATAR: THE WAY OF WATER
# 21                                   POKER FACE
# 22                             SEE HOW THEY RUN
# 23                      SPIDER-MAN: NO WAY HOME
# 24                  A CHRISTMAS STORY CHRISTMAS
# 25                           CHRISTMAS WITH YOU
# 26                                     THE MENU
# 27                           TICKET TO PARADISE
# 28                                     CAUSEWAY
# 29                           MY FATHER'S DRAGON
# 30                                  ON THE LINE
# 31                 WEIRD: THE AL YANKOVIC STORY
# 32                        LYLE, LYLE, CROCODILE
# 33                                 MY POLICEMAN
# 34                                  TERRIFIER 2
# 35  DOCTOR STRANGE IN THE MULTIVERSE OF MADNESS
# 36                               HALLOWEEN ENDS
# 37                                       AVATAR
# 38                                     MEDIEVAL
# 39                              ARMAGEDDON TIME
# 40                    THE SOCCER FOOTBALL MOVIE
# 41                               THE GOOD NURSE
# 42                                   THE BATMAN
# 43                TOM AND JERRY: SNOWMAN'S LAND
# 44                                BLACK PANTHER
# 45            EVERYTHING EVERYWHERE ALL AT ONCE
# 46                                        BEAST
# 47                                        PEARL
# 48                      JURASSIC WORLD DOMINION
# 49                             THE LAST MANHUNT
# 50                     MINIONS: THE RISE OF GRU
# 51                                PARADISE CITY
# 52                          TRIANGLE OF SADNESS
# 53                           ONE PIECE FILM RED
#
#                                                 Genre  \
# 0                          Action, Adventure, Fantasy
# 1                          Action, Adventure, Fantasy
# 2                                               Drama
# 3                              Kids & Family, Fantasy
# 4                   Holiday, Musical, Comedy, Fantasy
# 5                                              Sci-Fi
# 6   Mystery & Thriller, Drama, Action, Adventure, ...
# 7                                      Drama, Romance
# 8                                   Action, Adventure
# 9                                               Drama
# 10             Action, Adventure, History, Drama, War
# 52                                      Ruben Östlund    Oct 7, 2022  Limited
# 53                      Eiichiro Oda, Tsutomu Kuroiwa       Nov 4, 2022  Wide
#
#    Release Date (Streaming) box office Runtime                   Distributor  \
# 0              Nov 22, 2022    $165.1M   2h 5m         Warner Bros. Pictures
# 1                       NaN    $393.7M  2h 41m          Walt Disney Pictures
# 2              Jan 20, 2017      $5.1K  1h 19m                           NaN
# 3              Nov 18, 2022        NaN  1h 57m                       Netflix
# 4              Nov 18, 2022        NaN   2h 7m                     Apple TV+
# 5              Nov 22, 2020        NaN     14m                           NaN
# 6               Nov 4, 2022        NaN   2h 9m                       Netflix
# 7                       NaN        NaN  1h 55m                           NaN
# 8              Aug 22, 2022    $717.7M  2h 11m            Paramount Pictures
# 9              Nov 18, 2016        NaN  1h 26m                           NaN
# 10                      NaN     $67.1M  2h 15m              TriStar Pictures
# 11             Oct 25, 2022     $45.3M   2h 3m         Warner Bros. Pictures
# 12                      NaN        NaN  2h 35m                           NaN
# 13             Nov 18, 2022        NaN  1h 39m                           NaN
# 14                      NaN        NaN     52m                           NaN
# 15             Nov 18, 2022        NaN  1h 37m                     Lionsgate
# 16             Nov 15, 2022        NaN  1h 43m                           NaN
# 17              Sep 8, 2022    $343.2M   2h 5m          Walt Disney Pictures
# 18             Nov 18, 2022    $123.2M  2h 15m            Universal Pictures
# 19              Jan 4, 2017        NaN  1h 27m                           NaN
# 20                      NaN        NaN  3h 12m          20th Century Studios
# 21             Mar 19, 2018        NaN     11m                           NaN
# 22                      NaN      $9.6M  1h 38m          Searchlight Pictures
# 23                      NaN    $814.1M  2h 28m             Columbia Pictures
# 24             Nov 17, 2022        NaN  1h 41m                           NaN
# 25             Nov 17, 2022        NaN  1h 29m                       Netflix
# 26                      NaN     $24.6M  1h 47m          Searchlight Pictures
# 27             Mar 27, 2007        NaN  1h 10m             Republic Pictures
# 28              Nov 4, 2022        NaN  1h 32m                           A24
# 29                      NaN        NaN  1h 39m                           NaN
# 30                      NaN        NaN  1h 49m                           NaN
# 31              Nov 4, 2022        NaN  1h 48m              The Roku Channel
# 32                      NaN     $45.7M  1h 46m             Columbia Pictures
# 33              Nov 4, 2022        NaN  1h 53m                Amazon Studios
# 34                      NaN     $10.4M  2h 18m                      Cinedigm
# 35             Jun 22, 2022    $411.3M   2h 6m          Walt Disney Pictures
# 36             Oct 14, 2022     $64.0M  1h 51m            Universal Pictures
# 37             Apr 22, 2010     $23.5M  2h 35m              20th Century Fox
# 38                      NaN      $1.3M   2h 6m                    The Avenue
# 39                      NaN      $1.8M  1h 54m                Focus Features
# 40              Nov 9, 2022        NaN  1h 13m                           NaN
# 41             Oct 26, 2022        NaN  1h 56m                       Netflix
# 42             Apr 19, 2022    $369.3M  2h 56m         Warner Bros. Pictures
# 43             Nov 29, 2022        NaN  1h 12m                           NaN
# 44                      NaN        NaN     NaN                           NaN
# 45              Jun 7, 2022     $69.5M  2h 12m                           A24
# 46             Aug 21, 2018    $793.4K  1h 47m  Roadside Attractions, 30West
